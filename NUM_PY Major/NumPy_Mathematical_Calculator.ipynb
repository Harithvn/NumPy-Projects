# %% [markdown]
# # Numpy Mathematical Calculator
#
# ## Objective:
#
# To build a Python-based calculator using the **NumPy** library that performs:
#
# - Basic arithmetic operations
# - Statistical analysis
# - Array manipulation
#
# This project helps students understand how NumPy is used in real-world numerical computing tasks.
#
# ---
#
# ## Key Features:
#
# ### 1. Basic Arithmetic Operations
#
# - Addition, Subtraction, Multiplication, Division
# - Power operations between two arrays
#
# ### 2. Statistical Operations
#
# - Mean, Median, Standard Deviation, Variance
# - Minimum, Maximum, Sum, Product
# - Shape, Size, and Data Type
#
# ### 3. Array Manipulation
#
# - Reshaping arrays (when possible)
# - Sorting and Reverse Sorting
# - Unique value extraction
# - Accessing first and last elements
# - Filtering values greater than the mean

# %%
import numpy as np
from logging import exception

# %%
print("Numpy Mathematical Calculator")
print("------------------------------------")
try:
  a=input("enter the ele with space")
  arr1=np.array([int(i) for i in a.split()])
  b=input("enter the ele with space")
  arr2=np.array([int(i) for i in b.split()])
except ValueError:
  print("Enter Valid input")
  exit()
while True:
  print("Choice the operations")
  print("1.Arithmetic operations")
  print("2.Statistical Operations")
  print("3.Array Maipulation ")
  print("4. Exit")
  print("----------------------------------------")

  choice = input("enter your choice 1-4: ")
  if choice=='1':
    print("Arithmetic Operation")
    try:
      print(f"addition       :{arr1+arr2}")
      print(f"subtraction    :{arr1-arr2}")
      print(f"multiplication : {arr1*arr2}")
      print(f"division       : {arr1/arr2}")
      print(f"floor division :{arr1//arr2}")
      print(f"modulus division:{arr1%arr2}")
      print(f"exponensial     :{arr1**arr2}")
    except ValueError:
      print("Length of both array should be same")
    except exception as e:
      print(f" Error occurred : {e}")
      print("------------------------------------------")

  elif choice =='2':
    print("Statistical operations")
    try:
      arr=np.concatenate((arr1,arr2))
      print(f"concatenated array : {arr}")
      print(f" mean             :{np.mean(arr)}")
      print(f"median            :{np.median(arr)}")
      print(f"standard devation : {np.std(arr)}")
      print(f"variance          :{np.var(arr)}")
      print(f"minimum value     :{np.min(arr)}")
      print(f"maximum value     :{np.max(arr)}")
      print(f"sum               :{np.sum(arr)}")
      print(f"product           :{np.prod(arr)}")
      print(f"shape    : {arr.shape}")
      print(f"size     : {arr.size}")
      print(f"data type: {arr.dtype}")
    except exception as e:
      print(f" Error occurred : {e}")
      print("-----------------------------------------")

  elif choice=='3':
    print("Array manipulation")
    try:
      arr= np.concatenate((arr1,arr2))
      try:
        resh=int(input("enter the reshaping array 1 2 or 3"))
        if resh==2 or 1:
          row=int(input("enter rowsize"))
          col=int(input("enter colsize"))
          print(f"reshaping :\n {arr.reshape(row,col)}")
        else:
           row=int(input("enter rowsize"))
           col=int(input("enter colsize"))
           ele=int(input("enter elesize"))
           print(f"reshaping : {arr.reshape(row,col,ele)}")
      except ValueError:
        print("incomatiable shape")
      st=np.sort(arr)
      print(f"sorting {st}")
      f=np.flip(st)
      print(f"reverse sorting {f}")
      print(f"unique {np.unique(arr)}")
      print(f"first element {arr[0]}")
      print(f"last element{arr[-1]}")
      mean_val=np.mean(arr)
      print(f"filtering value :{mean_val}")
    except exception as e:
      print(f" error : {e}")
      print("----------------------------------")

  elif choice=='4':
    print("Thank you for using Numpy calaulater end")
    break
  else:
    print("Invalid Choice")
# Out:
# Numpy Mathematical Calculator
# ------------------------------------
# enter the ele with space23 45 34 57
# enter the ele with space78 65 43 14
# Choice the operations
# 1.Arithmetic operations
# 2.Statistical Operations
# 3.Array Maipulation
# 4. Exit
# ----------------------------------------
# enter your choice 1-4: 1
# Arithmetic Operation
# addition       :[101 110  77  71]
# subtraction    :[-55 -20  -9  43]
# multiplication : [1794 2925 1462  798]
# division       : [0.29487179 0.69230769 0.79069767 4.07142857]
# floor division :[0 0 0 4]
# modulus division:[23 45 34  1]
# exponensial     :[ 3741604096996058481 -7397211792996768467 -4121488550392758272
#  -6207602206036503087]
# Choice the operations
# 1.Arithmetic operations
# 2.Statistical Operations
# 3.Array Maipulation
# 4. Exit
# ----------------------------------------
# enter your choice 1-4: 2
# Statistical operations
# concatenated array : [23 45 34 57 78 65 43 14]
#  mean             :44.875
# median            :44.0
# standard devation : 20.00898235793115
# variance          :400.359375
# minimum value     :14
# maximum value     :78
# sum               :359
# product           :6122073976200
# shape    : (8,)
# size     : 8
# data type: int64
# Choice the operations
# 1.Arithmetic operations
# 2.Statistical Operations
# 3.Array Maipulation
# 4. Exit
# ----------------------------------------
# enter your choice 1-4: 3
# Array manipulation
# enter the reshaping array 1 2 or 32
# enter rowsize4
# enter colsize2
# reshaping :
#  [[23 45]
#  [34 57]
#  [78 65]
#  [43 14]]
# sorting [14 23 34 43 45 57 65 78]
# reverse sorting [78 65 57 45 43 34 23 14]
# unique [14 23 34 43 45 57 65 78]
# first element 23
# last element14
# filtering value :44.875
# Choice the operations
# 1.Arithmetic operations
# 2.Statistical Operations
# 3.Array Maipulation
# 4. Exit
# ----------------------------------------
# enter your choice 1-4: 4
# Thank you for using Numpy calaulater end
